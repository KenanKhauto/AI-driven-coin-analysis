# %%
from image_loader import CoinDataset
import torch
from torchvision import models
from torch.utils.data import DataLoader
from feature_extractor import FeatureExtractor

# %%
obverse_folder = r"F:\data_ba\kleinsilber_linz\kleinsilber_linz\obverse"
reverse_folder = r"F:\data_ba\kleinsilber_linz\kleinsilber_linz\reverse"

obverse_dataset = CoinDataset(
    obverse_folder=obverse_folder,  
    reverse_folder=reverse_folder,
    label="obverse",
    use_grayscale=True
)

reverse_dataset = CoinDataset(
    obverse_folder=obverse_folder,  
    reverse_folder=reverse_folder,
    label="reverse",
    use_grayscale=True
)

# %%
len(obverse_dataset)
# Out:
# 741

# %%
obverse_dataset.show_image(455)

# %%
extractor = FeatureExtractor(obverse_dataset, "obverse", device="cuda")
# Out:
# c:\Users\Kenan\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Kenan\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
extractor.extract_features("obverse_features_gray.npy", "obverse_filenames_gray.txt")
# Out:
# Batch 1 extracted!
# Batch 2 extracted!
# Batch 3 extracted!
# Batch 4 extracted!
# Batch 5 extracted!
# Batch 6 extracted!
# Batch 7 extracted!
# Batch 8 extracted!
# Batch 9 extracted!
# Batch 10 extracted!
# Batch 11 extracted!
# Batch 12 extracted!
# Batch 13 extracted!
# Batch 14 extracted!
# Batch 15 extracted!
# Batch 16 extracted!
# Batch 17 extracted!
# Batch 18 extracted!
# Batch 19 extracted!
# Batch 20 extracted!
# Batch 21 extracted!
# Batch 22 extracted!
# Batch 23 extracted!
# Batch 24 extracted!
# Batch 25 extracted!
# Batch 26 extracted!
# Batch 27 extracted!
# Batch 28 extracted!
# Batch 29 extracted!
# Batch 30 extracted!
# Batch 31 extracted!
# Batch 32 extracted!
# Batch 33 extracted!
# Batch 34 extracted!
# Batch 35 extracted!
# Batch 36 extracted!
# Batch 37 extracted!
# Batch 38 extracted!
# Batch 39 extracted!
# Batch 40 extracted!
# Batch 41 extracted!
# Batch 42 extracted!
# Batch 43 extracted!
# Batch 44 extracted!
# Batch 45 extracted!
# ...

# %%
extractor = FeatureExtractor(reverse_dataset, "reverse", device="cuda")
extractor.extract_features("reverse_features_gray.npy", "reverse_filenames_gray.txt")
# Out:
# c:\Users\Kenan\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Kenan\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Batch 1 extracted!
# Batch 2 extracted!
# Batch 3 extracted!
# Batch 4 extracted!
# Batch 5 extracted!
# Batch 6 extracted!
# Batch 7 extracted!
# Batch 8 extracted!
# Batch 9 extracted!
# Batch 10 extracted!
# Batch 11 extracted!
# Batch 12 extracted!
# Batch 13 extracted!
# Batch 14 extracted!
# ...
