# %%
from image_loader import CoinDataset
import torch
import matplotlib.pyplot as plt
import numpy as np
from utils import show_paired_images, preprocess_image

# %%
obverse_folder = r"F:\data_ba\kleinsilber_linz\kleinsilber_linz\obverse"
reverse_folder = r"F:\data_ba\kleinsilber_linz\kleinsilber_linz\reverse"


dataset_obverse = CoinDataset(obverse_folder, reverse_folder, label="obverse")
dataset_reverse = CoinDataset(obverse_folder, reverse_folder, label="reverse")
dataset_paired = CoinDataset(obverse_folder, reverse_folder, label="paired")

# %%
len(dataset_obverse)
# Out:
# 741

# %%
len(dataset_reverse)
# Out:
# 740

# %%
len(dataset_paired)
# Out:
# 465

# %%
dataset_obverse[1][0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
image = dataset_obverse[1][0].permute(1,2,0).numpy()

# %%
image.shape
# Out:
# (224, 224, 3)

# %%
plt.imshow(image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9131652..2.64].

# %%
# Mean and Std used during normalization (ImageNet statistics)
mean = torch.tensor([0.485, 0.456, 0.406]).view(1, 1, 3).numpy()  # Reshape to match [1, 1, C]
std = torch.tensor([0.229, 0.224, 0.225]).view(1, 1, 3).numpy()

# Reverse normalization
denormalized_image = (image * std) + mean

# %%
plt.imshow(denormalized_image)

# %%
import cv2

# %%
gray = cv2.cvtColor(denormalized_image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap="gray")

# %%
gray.shape
# Out:
# (224, 224)

# %%
image_path = r"F:\data_ba\kleinsilber_linz\kleinsilber_linz\obverse\00016a00.jpg"

# %%
img = cv2.imread(image_path)

# %%
img.shape
# Out:
# (621, 612, 3)
