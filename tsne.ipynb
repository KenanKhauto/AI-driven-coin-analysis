# %%
import matplotlib.pyplot as plt
from image_loader import CoinDataset
from torch.utils.data import DataLoader
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
obverse_folder = r"F:\data_ba\kleinsilber_linz\kleinsilber_linz\obverse"
reverse_folder = r"F:\data_ba\kleinsilber_linz\kleinsilber_linz\reverse"


dataset_obverse = CoinDataset(obverse_folder, reverse_folder, label="obverse")
dataset_reverse = CoinDataset(obverse_folder, reverse_folder, label="reverse")
dataset_obverse_g = CoinDataset(obverse_folder, reverse_folder, label="obverse", use_grayscale=True)
dataset_reverse_g = CoinDataset(obverse_folder, reverse_folder, label="reverse", use_grayscale=True)
# dataloader = DataLoader(dataset_obverse, batch_size=16, shuffle=False)

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from feature_extractor import FeatureExtractor
extractor = FeatureExtractor(dataset_obverse, "obverse")
features, filenames = extractor.load_features("obverse_features.npy", "obverse_filenames.txt")
# Reduce to 2D using t-SNE
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
features_2d = tsne.fit_transform(features)
# Plot
plt.figure(figsize=(8, 6))
plt.scatter(features_2d[:, 0], features_2d[:, 1], alpha=0.6)
plt.title("t-SNE Visualization of Extracted Coin Features (Obverse)")
plt.show()
# Out:
# c:\Users\Kenan\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Kenan\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# c:\Users\Kenan\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# ...

# %%
extractor = FeatureExtractor(dataset_obverse, "reverse")
features, filenames = extractor.load_features("reverse_features.npy", "reverse_filenames.txt")
# Reduce to 2D using t-SNE
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
features_2d = tsne.fit_transform(features)
# Plot
plt.figure(figsize=(8, 6))
plt.scatter(features_2d[:, 0], features_2d[:, 1], alpha=0.6)
plt.title("t-SNE Visualization of Extracted Coin Features (Reverse)")
plt.show()
# Out:
# c:\Users\Kenan\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Kenan\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from feature_extractor import FeatureExtractor
extractor = FeatureExtractor(dataset_obverse_g, "obverse")
features, filenames = extractor.load_features("obverse_features_gray.npy", "obverse_filenames_gray.txt")
# Reduce to 2D using t-SNE
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
features_2d = tsne.fit_transform(features)
# Plot
plt.figure(figsize=(8, 6))
plt.scatter(features_2d[:, 0], features_2d[:, 1], alpha=0.6)
plt.title("t-SNE Visualization of Extracted Coin Features (Obverse) -- Gray")
plt.show()
# Out:
# c:\Users\Kenan\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Kenan\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from feature_extractor import FeatureExtractor
extractor = FeatureExtractor(dataset_reverse_g, "reverse")
features, filenames = extractor.load_features("reverse_features_gray.npy", "reverse_filenames_gray.txt")
# Reduce to 2D using t-SNE
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
features_2d = tsne.fit_transform(features)
# Plot
plt.figure(figsize=(8, 6))
plt.scatter(features_2d[:, 0], features_2d[:, 1], alpha=0.6)
plt.title("t-SNE Visualization of Extracted Coin Features (Reverse) -- Gray")
plt.show()
# Out:
# c:\Users\Kenan\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Kenan\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
